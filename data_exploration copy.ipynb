# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path = "/Users/barnitorzsok/Documents/uni/masters/mlor/GroupAssignment-Data.csv"
df = pd.read_csv(path, header=None)

n = len(df)
n_cols = len(df.columns) - 2 #two response variables
new_col_names = ["y1", "y2"]
for i in range(n_cols):
    new_col_names.append(f"x{i+1}")
df.columns = new_col_names

print(f"number of observations: {n}\nnumber of columns: {n_cols} (plus the response variables)")
df.describe()
# Out:
# number of observations: 1000
#  number of columns: 55 (of which two are response variables)
#                 y1           y2             x1           x2            x3  \
# count  1000.000000  1000.000000    1000.000000  1000.000000   1000.000000
# mean      0.670000    38.496000  193966.802000    10.121000   1371.337000
# std       0.470448    13.187186  111900.741812     2.636534   9265.777009
# min       0.000000    17.000000   19303.000000     1.000000      0.000000
# 25%       0.000000    28.000000  120275.500000     9.000000      0.000000
# 50%       1.000000    37.000000  182114.000000    10.000000      0.000000
# 75%       1.000000    48.000000  242664.250000    13.000000      0.000000
# max       1.000000    90.000000  953589.000000    16.000000  99999.000000
#
#                x4           x5           x6           x7           x8  ...  \
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     94.82800    40.467000     0.067000     0.743000     0.036000  ...
# std     436.96023    11.257248     0.250147     0.437198     0.186383  ...
# min       0.00000     4.000000     0.000000     0.000000     0.000000  ...
# 25%       0.00000    40.000000     0.000000     0.000000     0.000000  ...
# 50%       0.00000    40.000000     0.000000     1.000000     0.000000  ...
# 75%       0.00000    45.000000     0.000000     1.000000     0.000000  ...
# max    4356.00000    99.000000     1.000000     1.000000     1.000000  ...
#
#                x46          x47          x48          x49          x50  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.255000     0.044000     0.142000     0.120000     0.053000
# std       0.436079     0.205198     0.349225     0.325124     0.224146
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                x51          x52          x53          x54          x55
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.044000     0.095000     0.016000     0.839000     0.246000
# std       0.205198     0.293362     0.125538     0.367715     0.430894
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     1.000000     0.000000
# 50%       0.000000     0.000000     0.000000     1.000000     0.000000
# 75%       0.000000     0.000000     0.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 57 columns]

# %%
binary_cols = []
numeric_cols = []

for column in df.columns:
    if column == "y1" or column == "y2":
        print("response var")
    elif len(pd.unique(df[column])) == 2 and df[column].min() == 0 and df[column].max() == 1:
        binary_cols.append(column)
    else:
        numeric_cols.append(column)
# Out:
# response var
# response var

# %%
df["y2"].hist()
# Out:
# <Axes: >

# %%
pd.unique(df["y2"])
# Out:
# array([44, 48, 67, 26, 21, 45, 69, 39, 18, 23, 50, 52, 47, 66, 53, 56, 27,
#        24, 28, 55, 37, 30, 33, 25, 31, 43, 42, 41, 19, 35, 32, 22, 36, 38,
#        49, 54, 34, 65, 20, 60, 46, 57, 17, 58, 59, 63, 61, 40, 51, 64, 90,
#        71, 62, 29, 76, 72, 73, 84, 82, 78, 74])

# %%
col = numeric_cols[4]
print(f"\ncolumn: {col}, unique values: {pd.unique(df[col])}")
df[col].hist()
# Out:
# column: x5, unique values: [50 40 45 20 38 30 24 43 10 37 60 55 65 70 15  5 48 25 23 35 16 44 12  6
#  52 57 32 39 17  7 72 36 80 28  9 26 96 42 19  4 18 14  8 56 47 41 46 99
#  77 75 31 66]
# <Axes: >

# %%
df[numeric_cols].describe()
# Out:
#                   x1           x2            x3          x4           x5  \
# count    1000.000000  1000.000000   1000.000000  1000.00000  1000.000000
# mean   193966.802000    10.121000   1371.337000    94.82800    40.467000
# std    111900.741812     2.636534   9265.777009   436.96023    11.257248
# min     19303.000000     1.000000      0.000000     0.00000     4.000000
# 25%    120275.500000     9.000000      0.000000     0.00000    40.000000
# 50%    182114.000000    10.000000      0.000000     0.00000    40.000000
# 75%    242664.250000    13.000000      0.000000     0.00000    45.000000
# max    953589.000000    16.000000  99999.000000  4356.00000    99.000000
#
#           x27     x33
# count  1000.0  1000.0
# mean      0.0     0.0
# std       0.0     0.0
# min       0.0     0.0
# 25%       0.0     0.0
# 50%       0.0     0.0
# 75%       0.0     0.0
# max       0.0     0.0

# %%
df.drop(columns=["x27", "x33"], axis=1, inplace=True)
numeric_cols.remove("x27")
numeric_cols.remove("x33")

# %%
correlation_matrix = df.corr()
fig, ax = plt.subplots(figsize = (12,10))
sns.heatmap(correlation_matrix, cmap="YlGnBu", ax=ax)
# Out:
# <Axes: >

# %%
corr = df[binary_cols].corr()
fig, ax = plt.subplots(figsize = (12,10))
sns.heatmap(corr, cmap="YlGnBu", ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize = (12,10))
corr = df[numeric_cols].corr()
sns.heatmap(corr, cmap="YlGnBu", ax=ax)
# Out:
# <Axes: >
